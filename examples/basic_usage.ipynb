# %% [markdown]
# # MyBackend basic usage
#
# Minimal smoke test that the plugin registers correctly and is reachable through the
# `Executor` factory of [qc-executor](https://github.com/flaqship/qc-executor). Replace the
# assertions with real backend usage as you implement the abstract methods.

# %%
from qc_executor.factory import Executor

# Importing the plugin package runs Executor.register() as a side effect.
import qc_executor_mybackend  # noqa: F401

print("Available backends:", Executor.available_backends())
assert "mybackend" in Executor.available_backends()

# %%
executor = Executor.create("mybackend", shots=1024)
executor

# %% [markdown]
# Once you've implemented `_statevector`, `_expectation_value`, etc., replace the cells
# below with real circuit/observable construction and execution, for example using
# `qc_executor.QuantumCircuit` and `qc_executor.QuantumOperator`.
